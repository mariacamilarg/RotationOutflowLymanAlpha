# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
num_puntos=30
num_offcenter=19

xs=zeros((num_puntos,num_offcenter))
ys=zeros((num_puntos,num_offcenter))

for i in range(num_offcenter):
    data_i=loadtxt('./data/V150/offcenter_'+str(0.1+0.05*i)+'.dat')
    xs[:,i]=data_i[:,0]
    ys[:,i]=data_i[:,1]

# %%
for i in range(num_offcenter):
    plot(xs[:,i],ys[:,i])

# %%
for i in range(7,num_offcenter):
    plot(xs[:,i],ys[:,i])
